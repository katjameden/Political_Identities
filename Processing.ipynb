# %% [markdown]
# # ParlaMint dataset processing
#
# Input data:
# - ParlaMint-SI_5.1.txt (text files)
# - ParlaMint-SI_5.1.connllu (metadata and sentiment metadata files)

# %%
import pandas as pd
import os

# %%
text_dir = "../Sample/ParlaMint-SI.txt"
conllu_dir = "../Sample/ParlaMint-SI.conllu"
output_file = "../ParlaMint-SI_data.csv"
